# %% [markdown]
# ### 1. `*` and `**`

# %%
'''
1. * and **
    1.1 in function arguments:
        *args	    packs extra positional arguments into a tuple
        **kwargs	packs extra keyword arguments into a dict   

    1.2 other way round, if not in arguments, means to unpack a tuple / dict back to the comma separated thing
'''

def demo(*args, **kwargs):
    print(args)
    print(kwargs)

demo(1, 2, a=3, b=4)

# %% [markdown]
# ### 2. pycache
#
# Python caches the compiled version of each module in the `__pycache__` directory under the name `module.version.pyc`
